# %% [markdown]
# # CASMI-16 Preprocessing Notebook
#
# This notebook downloads CASMI-16, which is stored across various files of different formats, and converts them into files usable by our evaluation scripts.
#
# In order to remove NIST-20 structure matches, this requires the TSVs generated by the NIST-20 preprocessing script.

# %%
# !wget http://www.casmi-contest.org/2016/CASMI2016_Cat2and3_Training.csv
# !wget http://www.casmi-contest.org/2016/CASMI2016_Cat2and3_Challenge.csv
# !wget http://www.casmi-contest.org/2016/solutions_casmi2016_cat2and3.csv
# !wget http://www.casmi-contest.org/2016/CASMI2016_Cat2and3_Training_positive_mgf.zip
# !wget http://www.casmi-contest.org/2016/CASMI2016_Cat2and3_Training_negative_mgf.zip
# !wget http://www.casmi-contest.org/2016/CASMI2016_Cat2and3_Challenge_positive_mgf.zip
# !wget http://www.casmi-contest.org/2016/CASMI2016_Cat2and3_Challenge_negative_mgf.zip

# %%
import numpy as np
import numpy.random as npr
import pandas as pd
from rdkit import Chem, RDLogger
RDLogger.DisableLog('rdApp.*')
import sys
sys.path.append('../..')

# %%
from src.io import read_mgf

# !for f in *.zip; do unzip $f; done
casmi_mgfs = !ls *.mgf

df = pd.Series(casmi_mgfs).apply(read_mgf)
df = pd.DataFrame.from_records(sum(df,[]))

casmi_train = pd.read_csv('CASMI2016_Cat2and3_Training.csv',index_col=0)
casmi_train = casmi_train.rename(columns={'IUPAC':'INCHI','challengename':'ChallengeName'})
casmi_test = pd.read_csv('solutions_casmi2016_cat2and3.csv',index_col=0)

df['ChallengeName'] = df['filename'].str.split('.').str[0]

df = df.merge(pd.concat([casmi_train,casmi_test]),on='ChallengeName')

for c in df.columns:
    if isinstance(df[c].iloc[0],str):
        df[c] = df[c].str.strip()

df['Spectrum'] = df['ChallengeName']
df['Precursor_type'] = df['ION_MODE'].map({'POSITIVE':'[M+H]+','NEGATIVE':'[M-H]-'})
df['Formula'] = df['INCHI'].str.split('/').str[1]
df['InChIKey'] = df['INCHIKEY']
df['InChIKey2D'] = df['INCHIKEY'].str.split('-').str[0]
df['PrecursorMZ'] = df['PRECURSOR_MZ']

# fill covariates with the modal value in the training set
df['NCE'] = 35.
df['Instrument'] = 'Thermo Finnigan Elite Orbitrap'

from pyteomics.mass import Composition
atom_types = {'C','H','N','O','P','S','F','Cl','Br','I'}
df = df.loc[df['Formula'].map(lambda x: {*Composition(formula=x)} <= atom_types)]

print(df.shape)
df.head(3)
# Out:
# Archive:  CASMI2016_Cat2and3_Challenge_negative_mgf.zip
#   inflating: Challenge-001.mgf
#   inflating: Challenge-002.mgf
#   inflating: Challenge-003.mgf
#   inflating: Challenge-004.mgf
#   inflating: Challenge-005.mgf
#   inflating: Challenge-006.mgf
#   inflating: Challenge-007.mgf
#   inflating: Challenge-008.mgf
#   inflating: Challenge-009.mgf
#   inflating: Challenge-010.mgf
#   inflating: Challenge-011.mgf
#   inflating: Challenge-012.mgf
#   inflating: Challenge-013.mgf
#   inflating: Challenge-014.mgf
#   inflating: Challenge-015.mgf
#   inflating: Challenge-016.mgf
#   inflating: Challenge-017.mgf
#   inflating: Challenge-018.mgf
#   inflating: Challenge-019.mgf
#   inflating: Challenge-020.mgf
#   inflating: Challenge-021.mgf
#   inflating: Challenge-022.mgf
#   inflating: Challenge-023.mgf
#   inflating: Challenge-024.mgf
#   inflating: Challenge-025.mgf
#   inflating: Challenge-026.mgf
#   inflating: Challenge-027.mgf
#   inflating: Challenge-028.mgf
#   inflating: Challenge-029.mgf
#   inflating: Challenge-030.mgf
#   inflating: Challenge-031.mgf
#   inflating: Challenge-032.mgf
#   inflating: Challenge-033.mgf
#   inflating: Challenge-034.mgf
#   inflating: Challenge-035.mgf
#   inflating: Challenge-036.mgf
#   inflating: Challenge-037.mgf
#   inflating: Challenge-038.mgf
#   inflating: Challenge-039.mgf
#   inflating: Challenge-040.mgf
#   inflating: Challenge-041.mgf
#   inflating: Challenge-042.mgf
#   inflating: Challenge-043.mgf
#   inflating: Challenge-044.mgf
#   inflating: Challenge-045.mgf
#   inflating: Challenge-046.mgf
#   inflating: Challenge-047.mgf
#   inflating: Challenge-048.mgf
#   inflating: Challenge-049.mgf
#   inflating: Challenge-050.mgf
#   inflating: Challenge-051.mgf
#   inflating: Challenge-052.mgf
#   inflating: Challenge-053.mgf
#   inflating: Challenge-054.mgf
#   inflating: Challenge-055.mgf
#   inflating: Challenge-056.mgf
#   inflating: Challenge-057.mgf
#   inflating: Challenge-058.mgf
#   inflating: Challenge-059.mgf
#   inflating: Challenge-060.mgf
#   inflating: Challenge-061.mgf
#   inflating: Challenge-062.mgf
#   inflating: Challenge-063.mgf
#   inflating: Challenge-064.mgf
#   inflating: Challenge-065.mgf
#   inflating: Challenge-066.mgf
#   inflating: Challenge-067.mgf
#   inflating: Challenge-068.mgf
#   inflating: Challenge-069.mgf
#   inflating: Challenge-070.mgf
#   inflating: Challenge-071.mgf
#   inflating: Challenge-072.mgf
#   inflating: Challenge-073.mgf
#   inflating: Challenge-074.mgf
#   inflating: Challenge-075.mgf
#   inflating: Challenge-076.mgf
#   inflating: Challenge-077.mgf
#   inflating: Challenge-078.mgf
#   inflating: Challenge-079.mgf
#   inflating: Challenge-080.mgf
#   inflating: Challenge-081.mgf
# Archive:  CASMI2016_Cat2and3_Challenge_positive_mgf.zip
#   inflating: Challenge-082.mgf
#   inflating: Challenge-083.mgf
#   inflating: Challenge-084.mgf
#   inflating: Challenge-085.mgf
#   inflating: Challenge-086.mgf
#   inflating: Challenge-087.mgf
#   inflating: Challenge-088.mgf
#   inflating: Challenge-089.mgf
#   inflating: Challenge-090.mgf
#   inflating: Challenge-091.mgf
#   inflating: Challenge-092.mgf
#   inflating: Challenge-093.mgf
#   inflating: Challenge-094.mgf
#   inflating: Challenge-095.mgf
#   inflating: Challenge-096.mgf
#   inflating: Challenge-097.mgf
#   inflating: Challenge-098.mgf
#   inflating: Challenge-099.mgf
#   inflating: Challenge-100.mgf
#   inflating: Challenge-101.mgf
#   inflating: Challenge-102.mgf
#   inflating: Challenge-103.mgf
#   inflating: Challenge-104.mgf
#   inflating: Challenge-105.mgf
#   inflating: Challenge-106.mgf
#   inflating: Challenge-107.mgf
#   inflating: Challenge-108.mgf
#   inflating: Challenge-109.mgf
#   inflating: Challenge-110.mgf
#   inflating: Challenge-111.mgf
#   inflating: Challenge-112.mgf
#   inflating: Challenge-113.mgf
#   inflating: Challenge-114.mgf
#   inflating: Challenge-115.mgf
#   inflating: Challenge-116.mgf
#   inflating: Challenge-117.mgf
#   inflating: Challenge-118.mgf
#   inflating: Challenge-119.mgf
#   inflating: Challenge-120.mgf
#   inflating: Challenge-121.mgf
#   inflating: Challenge-122.mgf
#   inflating: Challenge-123.mgf
#   inflating: Challenge-124.mgf
#   inflating: Challenge-125.mgf
#   inflating: Challenge-126.mgf
#   inflating: Challenge-127.mgf
#   inflating: Challenge-128.mgf
#   inflating: Challenge-129.mgf
#   inflating: Challenge-130.mgf
#   inflating: Challenge-131.mgf
#   inflating: Challenge-132.mgf
#   inflating: Challenge-133.mgf
#   inflating: Challenge-134.mgf
#   inflating: Challenge-135.mgf
#   inflating: Challenge-136.mgf
#   inflating: Challenge-137.mgf
#   inflating: Challenge-138.mgf
#   inflating: Challenge-139.mgf
#   inflating: Challenge-140.mgf
#   inflating: Challenge-141.mgf
#   inflating: Challenge-142.mgf
#   inflating: Challenge-143.mgf
#   inflating: Challenge-144.mgf
#   inflating: Challenge-145.mgf
#   inflating: Challenge-146.mgf
#   inflating: Challenge-147.mgf
#   inflating: Challenge-148.mgf
#   inflating: Challenge-149.mgf
#   inflating: Challenge-150.mgf
#   inflating: Challenge-151.mgf
#   inflating: Challenge-152.mgf
#   inflating: Challenge-153.mgf
#   inflating: Challenge-154.mgf
#   inflating: Challenge-155.mgf
#   inflating: Challenge-156.mgf
#   inflating: Challenge-157.mgf
#   inflating: Challenge-158.mgf
#   inflating: Challenge-159.mgf
#   inflating: Challenge-160.mgf
#   inflating: Challenge-161.mgf
#   inflating: Challenge-162.mgf
#   inflating: Challenge-163.mgf
#   inflating: Challenge-164.mgf
#   inflating: Challenge-165.mgf
#   inflating: Challenge-166.mgf
#   inflating: Challenge-167.mgf
#   inflating: Challenge-168.mgf
#   inflating: Challenge-169.mgf
#   inflating: Challenge-170.mgf
#   inflating: Challenge-171.mgf
#   inflating: Challenge-172.mgf
#   inflating: Challenge-173.mgf
#   inflating: Challenge-174.mgf
#   inflating: Challenge-175.mgf
#   inflating: Challenge-176.mgf
#   inflating: Challenge-177.mgf
#   inflating: Challenge-178.mgf
#   inflating: Challenge-179.mgf
#   inflating: Challenge-180.mgf
#   inflating: Challenge-181.mgf
#   inflating: Challenge-182.mgf
#   inflating: Challenge-183.mgf
#   inflating: Challenge-184.mgf
#   inflating: Challenge-185.mgf
#   inflating: Challenge-186.mgf
#   inflating: Challenge-187.mgf
#   inflating: Challenge-188.mgf
#   inflating: Challenge-189.mgf
#   inflating: Challenge-190.mgf
#   inflating: Challenge-191.mgf
#   inflating: Challenge-192.mgf
#   inflating: Challenge-193.mgf
#   inflating: Challenge-194.mgf
#   inflating: Challenge-195.mgf
#   inflating: Challenge-196.mgf
#   inflating: Challenge-197.mgf
#   inflating: Challenge-198.mgf
#   inflating: Challenge-199.mgf
#   inflating: Challenge-200.mgf
#   inflating: Challenge-201.mgf
#   inflating: Challenge-202.mgf
#   inflating: Challenge-203.mgf
#   inflating: Challenge-204.mgf
#   inflating: Challenge-205.mgf
#   inflating: Challenge-206.mgf
#   inflating: Challenge-207.mgf
#   inflating: Challenge-208.mgf
# Archive:  CASMI2016_Cat2and3_Training_negative_mgf.zip
#   inflating: Training-001.mgf
#   inflating: Training-002.mgf
#   inflating: Training-003.mgf
#   inflating: Training-004.mgf
#   inflating: Training-005.mgf
#   inflating: Training-006.mgf
#   inflating: Training-007.mgf
#   inflating: Training-008.mgf
#   inflating: Training-009.mgf
#   inflating: Training-010.mgf
#   inflating: Training-011.mgf
#   inflating: Training-012.mgf
#   inflating: Training-013.mgf
#   inflating: Training-014.mgf
#   inflating: Training-015.mgf
#   inflating: Training-016.mgf
#   inflating: Training-017.mgf
#   inflating: Training-018.mgf
#   inflating: Training-019.mgf
#   inflating: Training-020.mgf
#   inflating: Training-021.mgf
#   inflating: Training-022.mgf
#   inflating: Training-023.mgf
#   inflating: Training-024.mgf
#   inflating: Training-025.mgf
#   inflating: Training-026.mgf
#   inflating: Training-027.mgf
#   inflating: Training-028.mgf
#   inflating: Training-029.mgf
#   inflating: Training-030.mgf
#   inflating: Training-031.mgf
#   inflating: Training-032.mgf
#   inflating: Training-033.mgf
#   inflating: Training-034.mgf
#   inflating: Training-035.mgf
#   inflating: Training-036.mgf
#   inflating: Training-037.mgf
#   inflating: Training-038.mgf
#   inflating: Training-039.mgf
#   inflating: Training-040.mgf
#   inflating: Training-041.mgf
#   inflating: Training-042.mgf
#   inflating: Training-043.mgf
#   inflating: Training-044.mgf
#   inflating: Training-045.mgf
#   inflating: Training-046.mgf
#   inflating: Training-047.mgf
#   inflating: Training-048.mgf
#   inflating: Training-049.mgf
#   inflating: Training-050.mgf
#   inflating: Training-051.mgf
#   inflating: Training-052.mgf
#   inflating: Training-053.mgf
#   inflating: Training-054.mgf
#   inflating: Training-055.mgf
#   inflating: Training-056.mgf
#   inflating: Training-057.mgf
#   inflating: Training-058.mgf
# Archive:  CASMI2016_Cat2and3_Training_positive_mgf.zip
#   inflating: Training-059.mgf
#   inflating: Training-060.mgf
#   inflating: Training-061.mgf
#   inflating: Training-062.mgf
#   inflating: Training-063.mgf
#   inflating: Training-064.mgf
#   inflating: Training-065.mgf
#   inflating: Training-066.mgf
#   inflating: Training-067.mgf
#   inflating: Training-068.mgf
#   inflating: Training-069.mgf
#   inflating: Training-070.mgf
#   inflating: Training-071.mgf
#   inflating: Training-072.mgf
#   inflating: Training-073.mgf
#   inflating: Training-074.mgf
#   inflating: Training-075.mgf
#   inflating: Training-076.mgf
#   inflating: Training-077.mgf
#   inflating: Training-078.mgf
#   inflating: Training-079.mgf
#   inflating: Training-080.mgf
#   inflating: Training-081.mgf
#   inflating: Training-082.mgf
#   inflating: Training-083.mgf
#   inflating: Training-084.mgf
#   inflating: Training-085.mgf
#   inflating: Training-086.mgf
#   inflating: Training-087.mgf
#   inflating: Training-088.mgf
#   inflating: Training-089.mgf
#   inflating: Training-090.mgf
#   inflating: Training-091.mgf
#   inflating: Training-092.mgf
#   inflating: Training-093.mgf
#   inflating: Training-094.mgf
#   inflating: Training-095.mgf
#   inflating: Training-096.mgf
#   inflating: Training-097.mgf
#   inflating: Training-098.mgf
#   inflating: Training-099.mgf
#   inflating: Training-100.mgf
#   inflating: Training-101.mgf
#   inflating: Training-102.mgf
#   inflating: Training-103.mgf
#   inflating: Training-104.mgf
#   inflating: Training-105.mgf
#   inflating: Training-106.mgf
#   inflating: Training-107.mgf
#   inflating: Training-108.mgf
#   inflating: Training-109.mgf
#   inflating: Training-110.mgf
#   inflating: Training-111.mgf
#   inflating: Training-112.mgf
#   inflating: Training-113.mgf
#   inflating: Training-114.mgf
#   inflating: Training-115.mgf
#   inflating: Training-116.mgf
#   inflating: Training-117.mgf
#   inflating: Training-118.mgf
#   inflating: Training-119.mgf
#   inflating: Training-120.mgf
#   inflating: Training-121.mgf
#   inflating: Training-122.mgf
#   inflating: Training-123.mgf
#   inflating: Training-124.mgf
#   inflating: Training-125.mgf
#   inflating: Training-126.mgf
#   inflating: Training-127.mgf
#   inflating: Training-128.mgf
#   inflating: Training-129.mgf
#   inflating: Training-130.mgf
#   inflating: Training-131.mgf
#   inflating: Training-132.mgf
#   inflating: Training-133.mgf
#   inflating: Training-134.mgf
#   inflating: Training-135.mgf
#   inflating: Training-136.mgf
#   inflating: Training-137.mgf
#   inflating: Training-138.mgf
#   inflating: Training-139.mgf
#   inflating: Training-140.mgf
#   inflating: Training-141.mgf
#   inflating: Training-142.mgf
#   inflating: Training-143.mgf
#   inflating: Training-144.mgf
#   inflating: Training-145.mgf
#   inflating: Training-146.mgf
#   inflating: Training-147.mgf
#   inflating: Training-148.mgf
#   inflating: Training-149.mgf
#   inflating: Training-150.mgf
#   inflating: Training-151.mgf
#   inflating: Training-152.mgf
#   inflating: Training-153.mgf
#   inflating: Training-154.mgf
#   inflating: Training-155.mgf
#   inflating: Training-156.mgf
#   inflating: Training-157.mgf
#   inflating: Training-158.mgf
#   inflating: Training-159.mgf
#   inflating: Training-160.mgf
#   inflating: Training-161.mgf
#   inflating: Training-162.mgf
#   inflating: Training-163.mgf
#   inflating: Training-164.mgf
#   inflating: Training-165.mgf
#   inflating: Training-166.mgf
#   inflating: Training-167.mgf
#   inflating: Training-168.mgf
#   inflating: Training-169.mgf
#   inflating: Training-170.mgf
#   inflating: Training-171.mgf
#   inflating: Training-172.mgf
#   inflating: Training-173.mgf
#   inflating: Training-174.mgf
#   inflating: Training-175.mgf
#   inflating: Training-176.mgf
#   inflating: Training-177.mgf
#   inflating: Training-178.mgf
#   inflating: Training-179.mgf
#   inflating: Training-180.mgf
#   inflating: Training-181.mgf
#   inflating: Training-182.mgf
#   inflating: Training-183.mgf
#   inflating: Training-184.mgf
#   inflating: Training-185.mgf
#   inflating: Training-186.mgf
#   inflating: Training-187.mgf
#   inflating: Training-188.mgf
#   inflating: Training-189.mgf
#   inflating: Training-190.mgf
#   inflating: Training-191.mgf
#   inflating: Training-192.mgf
#   inflating: Training-193.mgf
#   inflating: Training-194.mgf
#   inflating: Training-195.mgf
#   inflating: Training-196.mgf
#   inflating: Training-197.mgf
#   inflating: Training-198.mgf
#   inflating: Training-199.mgf
#   inflating: Training-200.mgf
#   inflating: Training-201.mgf
#   inflating: Training-202.mgf
#   inflating: Training-203.mgf
#   inflating: Training-204.mgf
#   inflating: Training-205.mgf
#   inflating: Training-206.mgf
#   inflating: Training-207.mgf
#   inflating: Training-208.mgf
#   inflating: Training-209.mgf
#   inflating: Training-210.mgf
#   inflating: Training-211.mgf
#   inflating: Training-212.mgf
#   inflating: Training-213.mgf
#   inflating: Training-214.mgf
#   inflating: Training-215.mgf
#   inflating: Training-216.mgf
#   inflating: Training-217.mgf
#   inflating: Training-218.mgf
#   inflating: Training-219.mgf
#   inflating: Training-220.mgf
#   inflating: Training-221.mgf
#   inflating: Training-222.mgf
#   inflating: Training-223.mgf
#   inflating: Training-224.mgf
#   inflating: Training-225.mgf
#   inflating: Training-226.mgf
#   inflating: Training-227.mgf
#   inflating: Training-228.mgf
#   inflating: Training-229.mgf
#   inflating: Training-230.mgf
#   inflating: Training-231.mgf
#   inflating: Training-232.mgf
#   inflating: Training-233.mgf
#   inflating: Training-234.mgf
#   inflating: Training-235.mgf
#   inflating: Training-236.mgf
#   inflating: Training-237.mgf
#   inflating: Training-238.mgf
#   inflating: Training-239.mgf
#   inflating: Training-240.mgf
#   inflating: Training-241.mgf
#   inflating: Training-242.mgf
#   inflating: Training-243.mgf
#   inflating: Training-244.mgf
#   inflating: Training-245.mgf
#   inflating: Training-246.mgf
#   inflating: Training-247.mgf
#   inflating: Training-248.mgf
#   inflating: Training-249.mgf
#   inflating: Training-250.mgf
#   inflating: Training-251.mgf
#   inflating: Training-252.mgf
#   inflating: Training-253.mgf
#   inflating: Training-254.mgf
#   inflating: Training-255.mgf
#   inflating: Training-256.mgf
#   inflating: Training-257.mgf
#   inflating: Training-258.mgf
#   inflating: Training-259.mgf
#   inflating: Training-260.mgf
#   inflating: Training-261.mgf
#   inflating: Training-262.mgf
#   inflating: Training-263.mgf
#   inflating: Training-264.mgf
#   inflating: Training-265.mgf
#   inflating: Training-266.mgf
#   inflating: Training-267.mgf
#   inflating: Training-268.mgf
#   inflating: Training-269.mgf
#   inflating: Training-270.mgf
#   inflating: Training-271.mgf
#   inflating: Training-272.mgf
#   inflating: Training-273.mgf
#   inflating: Training-274.mgf
#   inflating: Training-275.mgf
#   inflating: Training-276.mgf
#   inflating: Training-277.mgf
#   inflating: Training-278.mgf
#   inflating: Training-279.mgf
#   inflating: Training-280.mgf
#   inflating: Training-281.mgf
#   inflating: Training-282.mgf
#   inflating: Training-283.mgf
#   inflating: Training-284.mgf
#   inflating: Training-285.mgf
#   inflating: Training-286.mgf
#   inflating: Training-287.mgf
#   inflating: Training-288.mgf
#   inflating: Training-289.mgf
#   inflating: Training-290.mgf
#   inflating: Training-291.mgf
#   inflating: Training-292.mgf
#   inflating: Training-293.mgf
#   inflating: Training-294.mgf
#   inflating: Training-295.mgf
#   inflating: Training-296.mgf
#   inflating: Training-297.mgf
#   inflating: Training-298.mgf
#   inflating: Training-299.mgf
#   inflating: Training-300.mgf
#   inflating: Training-301.mgf
#   inflating: Training-302.mgf
#   inflating: Training-303.mgf
#   inflating: Training-304.mgf
#   inflating: Training-305.mgf
#   inflating: Training-306.mgf
#   inflating: Training-307.mgf
#   inflating: Training-308.mgf
#   inflating: Training-309.mgf
#   inflating: Training-310.mgf
#   inflating: Training-311.mgf
#   inflating: Training-312.mgf
# (519, 24)
#             filename  precursor_mz  precursor_charge  \
# 0  Challenge-001.mgf      222.0230                 1
# 1  Challenge-002.mgf      286.9690                 1
# 2  Challenge-003.mgf      223.0071                 1
#
#                                                  mzs  \
# 0  [107.0491, 131.0502, 157.0533, 158.0611, 222.023]
# 1  [143.0503, 159.0455, 206.0044, 207.0122, 223.0...
# 2  [143.0502, 158.0374, 159.0451, 221.9993, 223.007]
#
#                                          intensities  ChallengeName  \
# 0  [11496.1, 12601.5, 11285.7, 2146837.0, 1058536...  Challenge-001
# 1  [730689.2, 4983.9, 6564.5, 2890253.8, 15932.3,...  Challenge-002
# 2  [255766.4, 55048.3, 832484.6, 13045.9, 7569678.5]  Challenge-003
#
#    PRECURSOR_MZ  ION_MODE     RT  nPeaks  ...   CSID   PC_CID       Spectrum  \
# 0      222.0230  NEGATIVE  0.803       5  ...   8101   8408.0  Challenge-001
# 1      286.9690  NEGATIVE  1.964       6  ...  60073  66707.0  Challenge-002
# 2      223.0071  NEGATIVE  2.371       5  ...  60378  67025.0  Challenge-003
#
#   Precursor_type    Formula                     InChIKey      InChIKey2D  \
# 0         [M-H]-  C10H9NO3S  UWPJYQYRSWYIGZ-UHFFFAOYSA-N  UWPJYQYRSWYIGZ
# 1         [M-H]-  C10H8O6S2  VILFVXYKHXVYAB-UHFFFAOYSA-N  VILFVXYKHXVYAB
# 2         [M-H]-   C10H8O4S  YLKCHWCYYNKADS-UHFFFAOYSA-N  YLKCHWCYYNKADS
#
#   PrecursorMZ   NCE                      Instrument
# 0    222.0230  35.0  Thermo Finnigan Elite Orbitrap
# 1    286.9690  35.0  Thermo Finnigan Elite Orbitrap
# 2    223.0071  35.0  Thermo Finnigan Elite Orbitrap
#
# [3 rows x 24 columns]

# %%
# remove 2D structure matches to NIST
nist_smiles = !cat ../nist-20/hr_msms_nist_*.tsv | cut -f2 | sort | uniq
nist_inchikeys = [Chem.MolToInchiKey(Chem.MolFromSmiles(s)) for s in nist_smiles]
nist_inchikey2ds = {x.split('-')[0] for x in nist_inchikeys}

df = df.loc[~df['InChIKey2D'].isin(nist_inchikey2ds)]

print(len(df),'spectra')
print(df['InChIKey'].nunique(),'structures')
# Out:
# 166 spectra
# 151 structures

# %%
from src.io import write_msp

tsv_path = 'casmi-16.tsv'
cols = ['Spectrum','SMILES','Precursor_type','NCE','Instrument']
df[cols].to_csv(tsv_path, sep='\t', header=False, index=False)

msp_path = 'casmi-16.msp'
cols += ['InChIKey','Formula','PrecursorMZ']
write_msp(
    msp_path,
    df['mzs'].tolist(), 
    df['intensities'].tolist(),
    **{c: df[c].tolist() for c in cols}
)

# %%
# clean up
# !rm *.mgf
